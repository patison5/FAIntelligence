# %%
# Ссылка на гугл коллаб
# https://colab.research.google.com/drive/1a6dbpcdTSj8CeGr2c_79m5ZwRrRopZ_c?usp=sharing

# %% [markdown]
# # Explorary data Analysis

# %% [markdown]
# ### Импортирование зависимостей

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation

# %matplotlib inline     
sns.set(color_codes=True)

# %%
# !ls -la
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Jan 10 13:07 .
# drwxr-xr-x 1 root root 4096 Jan 10 13:01 ..
# drwxr-xr-x 4 root root 4096 Dec 23 14:32 .config
# drwxr-xr-x 2 root root 4096 Jan 10 13:07 .ipynb_checkpoints
# drwxr-xr-x 2 root root 4096 Jan 10 13:08 Kaggle
# drwxr-xr-x 1 root root 4096 Dec 23 14:32 sample_data

# %% [markdown]
# fixed acidity - фиксированная кислотность <br>
# volatile acidity - летучая кислотность <br>
# citric acid - лимонная кислота <br>
# residual sugar - остаточный сахар <br>
# chlorides - хлориды <br>
# free sulfur dioxide - свободный диоксид серы <br>
# total sulfur dioxide- диоксид серы общий <br>
# density - плотность <br>
# pH - рН <br>
# sulphates - сульфаты <br>

# %% [markdown]
# ### Загрузка данных и отображение фрейма

# %%
df = pd.read_csv("Kaggle/winequality-red.csv")
df.head(5) # Показываем первые 5 элементов
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.tail(5) # Показываем последние 5 элементов
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Проверка типов данных

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ### Переименовывание ячеек

# %%
df = df.rename(columns={
    "fixed acidity": "FA",
    "volatile acidity": "VA",
    "citric acid": "CA",
    "residual sugar": "RS",
    "free sulfur dioxide": "FSD",
    "total sulfur dioxide": "total_SD"
})
df.head(5)
# Out:
#      FA    VA    CA   RS  chlorides  ...  density    pH  sulphates  alcohol  quality
# 0   7.4  0.70  0.00  1.9      0.076  ...   0.9978  3.51       0.56      9.4        5
# 1   7.8  0.88  0.00  2.6      0.098  ...   0.9968  3.20       0.68      9.8        5
# 2   7.8  0.76  0.04  2.3      0.092  ...   0.9970  3.26       0.65      9.8        5
# 3  11.2  0.28  0.56  1.9      0.075  ...   0.9980  3.16       0.58      9.8        6
# 4   7.4  0.70  0.00  1.9      0.076  ...   0.9978  3.51       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# ### Удаление дупликатов

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (240, 12)

# %%
df.count()
# Out:
# FA           1599
# VA           1599
# CA           1599
# RS           1599
# chlorides    1599
# FSD          1599
# total_SD     1599
# density      1599
# pH           1599
# sulphates    1599
# alcohol      1599
# quality      1599
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#      FA    VA    CA   RS  chlorides  ...  density    pH  sulphates  alcohol  quality
# 0   7.4  0.70  0.00  1.9      0.076  ...   0.9978  3.51       0.56      9.4        5
# 1   7.8  0.88  0.00  2.6      0.098  ...   0.9968  3.20       0.68      9.8        5
# 2   7.8  0.76  0.04  2.3      0.092  ...   0.9970  3.26       0.65      9.8        5
# 3  11.2  0.28  0.56  1.9      0.075  ...   0.9980  3.16       0.58      9.8        6
# 5   7.4  0.66  0.00  1.8      0.075  ...   0.9978  3.51       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.count()
# Out:
# FA           1359
# VA           1359
# CA           1359
# RS           1359
# chlorides    1359
# FSD          1359
# total_SD     1359
# density      1359
# pH           1359
# sulphates    1359
# alcohol      1359
# quality      1359
# dtype: int64

# %% [markdown]
# ### Детектирование и удаление пустых или нулевых ячеек

# %%
print(df.isnull().sum()) # Кол-во нулевых ячеек.
# Out:
# FA           0
# VA           0
# CA           0
# RS           0
# chlorides    0
# FSD          0
# total_SD     0
# density      0
# pH           0
# sulphates    0
# alcohol      0
# quality      0
# dtype: int64

# %% [markdown]
# ### Определение выброса

# %%
sns.boxplot(x=df["alcohol"]) # Алкоголь

# %%
sns.boxplot(x=df["quality"]) # Качество

# %%
sns.boxplot(x=df["density"]) # Алкоголь

# %%
sns.boxplot(x=df["VA"]) # Алкоголь

# %%
_, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 4))
sns.boxplot(data=df["VA"], ax=axes[0])
sns.violinplot(data=df["VA"], ax=axes[1]);

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# FA            2.10000
# VA            0.25000
# CA            0.34000
# RS            0.70000
# chlorides     0.02100
# FSD          14.00000
# total_SD     41.00000
# density       0.00222
# pH            0.19000
# sulphates     0.18000
# alcohol       1.60000
# quality       1.00000
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)] # Применение техники IQR
df.shape
# Out:
# (1005, 12)

# %% [markdown]
# ### Отрисовка диаграмм

# %% [markdown]
# #### Гистограммы

# %%
df.quality.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Качество вин")
plt.ylabel('Кол-во вин данного кач-ва')
plt.xlabel('Качество вина');

# %% [markdown]
# ### Карты тепла
# Тепловые карты — это тип графика, который необходим, когда нам нужно найти зависимые переменные. Один из лучших способов найти взаимосвязь между функциями — использовать тепловые карты.

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                  FA        VA        CA  ...  sulphates   alcohol   quality
# FA         1.000000 -0.282019  0.655777  ...   0.185839 -0.025770  0.121315
# VA        -0.282019  1.000000 -0.621121  ...  -0.308814 -0.222085 -0.348293
# CA         0.655777 -0.621121  1.000000  ...   0.270070  0.152067  0.220871
# RS         0.239487  0.021976  0.155535  ...   0.053014  0.091426  0.013534
# chlorides  0.202368  0.124282  0.065903  ...  -0.069210 -0.291450 -0.183684
# FSD       -0.144925 -0.018433 -0.067158  ...   0.089043 -0.050641 -0.015978
# total_SD  -0.087810  0.099376  0.011869  ...  -0.060509 -0.265482 -0.208359
# density    0.610015  0.043580  0.289552  ...   0.091304 -0.538401 -0.215042
# pH        -0.692128  0.241762 -0.477620  ...   0.005097  0.118311 -0.061311
# sulphates  0.185839 -0.308814  0.270070  ...   1.000000  0.268061  0.418719
# alcohol   -0.025770 -0.222085  0.152067  ...   0.268061  1.000000  0.493492
# quality    0.121315 -0.348293  0.220871  ...   0.418719  0.493492  1.000000
#
# [12 rows x 12 columns]

# %% [markdown]
# #### Диаграмма рассеивания
# Используется для нахождения кореляции между двумя переменными. Здесь графики разброса построены между качеством вина и алкогольной составляющей

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['quality'], df['alcohol'])
ax.set_xlabel('quality')
ax.set_ylabel('alcohol')
plt.show()

# %%
sns.jointplot(x="quality", y="alcohol", data=df, kind="scatter");

# %%
sns.jointplot(
    "quality", "alcohol", data=df, kind="kde", color="g"
);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# `pairplot()` may become very slow with the SVG format
# %config InlineBackend.figure_format = 'png'
sns.pairplot(df);

# %%
sns.lmplot(
    "VA", "alcohol", data=df, hue="quality", fit_reg=False
);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # ML Course 1

# %%
df
# Out:
#         FA     VA    CA   RS  ...    pH  sulphates  alcohol  quality
# 0      7.4  0.700  0.00  1.9  ...  3.51       0.56      9.4        5
# 1      7.8  0.880  0.00  2.6  ...  3.20       0.68      9.8        5
# 2      7.8  0.760  0.04  2.3  ...  3.26       0.65      9.8        5
# 3     11.2  0.280  0.56  1.9  ...  3.16       0.58      9.8        6
# 5      7.4  0.660  0.00  1.8  ...  3.51       0.56      9.4        5
# ...    ...    ...   ...  ...  ...   ...        ...      ...      ...
# 1593   6.8  0.620  0.08  1.9  ...  3.42       0.82      9.5        6
# 1594   6.2  0.600  0.08  2.0  ...  3.45       0.58     10.5        5
# 1595   5.9  0.550  0.10  2.2  ...  3.52       0.76     11.2        6
# 1597   5.9  0.645  0.12  2.0  ...  3.57       0.71     10.2        5
# 1598   6.0  0.310  0.47  3.6  ...  3.39       0.66     11.0        6
#
# [1005 rows x 12 columns]

# %%
df["quality"].mean()
# Out:
# 5.616915422885572

# %%
df[df["quality"] == 6].mean()
# Out:
# FA            8.215130
# VA            0.496418
# CA            0.260875
# RS            2.188534
# chlorides     0.076927
# FSD          15.352246
# total_SD     38.706856
# density       0.996433
# pH            3.326454
# sulphates     0.652861
# alcohol      10.601300
# quality       6.000000
# dtype: float64

# %%
df[df["quality"] == 6]["alcohol"].mean()
# Out:
# 10.601300236406626

# %%
df.loc[0:7, "density":"quality"]
# Out:
#    density    pH  sulphates  alcohol  quality
# 0   0.9978  3.51       0.56      9.4        5
# 1   0.9968  3.20       0.68      9.8        5
# 2   0.9970  3.26       0.65      9.8        5
# 3   0.9980  3.16       0.58      9.8        6
# 5   0.9978  3.51       0.56      9.4        5
# 6   0.9964  3.30       0.46      9.4        5
# 7   0.9946  3.39       0.47     10.0        7

# %%
df.iloc[0:5, 0:3]
# Out:
#      FA    VA    CA
# 0   7.4  0.70  0.00
# 1   7.8  0.88  0.00
# 2   7.8  0.76  0.04
# 3  11.2  0.28  0.56
# 5   7.4  0.66  0.00

# %%
df[-1:]
# Out:
#        FA    VA    CA   RS  ...    pH  sulphates  alcohol  quality
# 1598  6.0  0.31  0.47  3.6  ...  3.39       0.66     11.0        6
#
# [1 rows x 12 columns]

# %%
df.apply(np.max)
# Out:
# FA            12.300
# VA             1.010
# CA             0.730
# RS             3.650
# chlorides      0.122
# FSD           42.000
# total_SD     124.000
# density        1.001
# pH             3.680
# sulphates      0.980
# alcohol       13.400
# quality        7.000
# dtype: float64

# %%
df[df["quality"].apply(lambda alcohol: alcohol > 5)].head()
# Out:
#       FA    VA    CA   RS  ...    pH  sulphates  alcohol  quality
# 3   11.2  0.28  0.56  1.9  ...  3.16       0.58      9.8        6
# 7    7.3  0.65  0.00  1.2  ...  3.39       0.47     10.0        7
# 8    7.8  0.58  0.02  2.0  ...  3.36       0.57      9.5        7
# 16   8.5  0.28  0.56  1.8  ...  3.30       0.75     10.5        7
# 20   8.9  0.22  0.48  1.8  ...  3.39       0.53      9.4        6
#
# [5 rows x 12 columns]

# %%
# смысл понятен, но в данном датасете отсутствуют булевые столбцы
d = {"true": False, "false": True}
# df["Iquality"] = df["quality"].map(d)
# df.head()

# %%
columns_to_show = ["alcohol", "quality", "FA"]

df.groupby(["quality"])[columns_to_show].describe(percentiles=[])
# Out:
#         alcohol                            ...        FA
#           count       mean       std  min  ...       std  min  50%   max
# quality                                    ...
# 4          33.0  10.001515  0.713758  9.0  ...  1.362630  5.6  8.0  12.0
# 5         434.0   9.891705  0.702100  9.0  ...  1.339602  5.2  7.7  12.3
# 6         423.0  10.601300  0.954617  8.7  ...  1.535414  5.4  7.8  12.3
# 7         115.0  11.429130  0.902943  9.5  ...  1.652259  5.1  8.5  12.0
#
# [4 rows x 18 columns]

# %%
columns_to_show = ["alcohol", "quality", "FA"]

df.groupby(["quality"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#            alcohol                       ...        FA
#               mean       std amin  amax  ...      mean       std amin  amax
# quality                                  ...
# 4        10.001515  0.713758  9.0  11.5  ...  8.036364  1.362630  5.6  12.0
# 5         9.891705  0.702100  9.0  13.0  ...  8.007834  1.339602  5.2  12.3
# 6        10.601300  0.954617  8.7  13.3  ...  8.215130  1.535414  5.4  12.3
# 7        11.429130  0.902943  9.5  13.4  ...  8.628696  1.652259  5.1  12.0
#
# [4 rows x 12 columns]

# %%
pd.crosstab(df["quality"], df["alcohol"])
# Out:
# alcohol  8.70   9.00   9.05   ...  13.00  13.30  13.40
# quality                       ...
# 4            0      1      1  ...      0      0      0
# 5            0      6      0  ...      2      0      0
# 6            2      5      0  ...      0      1      0
# 7            0      0      0  ...      1      1      1
#
# [4 rows x 51 columns]

# %%
pd.crosstab(df["quality"], df["alcohol"], normalize=True)
# Out:
# alcohol    8.70      9.00      9.05   ...     13.00     13.30     13.40
# quality                               ...
# 4        0.00000  0.000995  0.000995  ...  0.000000  0.000000  0.000000
# 5        0.00000  0.005970  0.000000  ...  0.001990  0.000000  0.000000
# 6        0.00199  0.004975  0.000000  ...  0.000000  0.000995  0.000000
# 7        0.00000  0.000000  0.000000  ...  0.000995  0.000995  0.000995
#
# [4 rows x 51 columns]

# %%
df.pivot_table(
    ["quality", "alcohol", "FA"],
    ["CA"],
    aggfunc="mean",
).head(5)
# Out:
#             FA    alcohol   quality
# CA
# 0.00  7.206818  10.307955  5.397727
# 0.01  7.104762  10.900000  5.809524
# 0.02  6.996875  10.413021  5.750000
# 0.03  7.135000  10.250000  5.250000
# 0.04  7.163158   9.936842  5.315789

# %%
df["SOME SHIT"] = (
    df["FA"]
    + df["VA"]
    + df["CA"]
)
df.head()
# Out:
#      FA    VA    CA   RS  ...  sulphates  alcohol  quality  SOME SHIT
# 0   7.4  0.70  0.00  1.9  ...       0.56      9.4        5       8.10
# 1   7.8  0.88  0.00  2.6  ...       0.68      9.8        5       8.68
# 2   7.8  0.76  0.04  2.3  ...       0.65      9.8        5       8.60
# 3  11.2  0.28  0.56  1.9  ...       0.58      9.8        6      12.04
# 5   7.4  0.66  0.00  1.8  ...       0.56      9.4        5       8.06
#
# [5 rows x 13 columns]

# %%
# get rid of just created columns
df.drop(["SOME SHIT"], axis=1, inplace=True)
# and here’s how you can delete rows
df.drop([1, 2]).head()
# Out:
#      FA    VA    CA   RS  chlorides  ...  density    pH  sulphates  alcohol  quality
# 0   7.4  0.70  0.00  1.9      0.076  ...   0.9978  3.51       0.56      9.4        5
# 3  11.2  0.28  0.56  1.9      0.075  ...   0.9980  3.16       0.58      9.8        6
# 5   7.4  0.66  0.00  1.8      0.075  ...   0.9978  3.51       0.56      9.4        5
# 6   7.9  0.60  0.06  1.6      0.069  ...   0.9964  3.30       0.46      9.4        5
# 7   7.3  0.65  0.00  1.2      0.065  ...   0.9946  3.39       0.47     10.0        7
#
# [5 rows x 12 columns]
