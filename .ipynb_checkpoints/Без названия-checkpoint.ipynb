# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

from matplotlib.pyplot import figure

# %%
days = [20, 15, 17, 12, 19, 10, 18, 20, 13, 18]
experiments = [9.2, 1.4]

N = 20
# Out:
# 162

# %%
B = np.array([3])
A = np.array([1, 2, 2])
print(A)
B = np.append( B , A )
print(B)
# Out:
# [1 2 2]
# [3 1 2 2]

# %%
all_1 = np.array([])
all_2 = np.array([])

sr_1 = []
sr_2 = []

for i, j in enumerate(days):
    for m in experiments:                
        if (m == 9.2):
            users_times = np.ones(j) * m
            random_values = np.random.normal(0, 1, j)
            res = users_times + random_values
            all_1 = np.append( all_1 , res )
            sr_1.append(sum(res) / len(res))
        else:
            users_times = np.ones(j) * m
            random_values = np.random.normal(0, 0.2, j)
            res = users_times + random_values
            all_2 = np.append( all_2 , res )
            sr_2.append(sum(res) / len(res))
        

print(sr_1)
print("")
print(sr_2)

import random

x = np.arange(0,10,1)

fig,ax = plt.subplots()

y_mean_1 = [np.mean(sr_1)]*len(sr_1)
data_line = ax.plot(x, sr_1, label='Время', marker='o')
mean_line = ax.plot(x, y_mean_1, label='Среднее', linestyle='--')

legend = ax.legend(loc='upper right')

plt.figure(figsize=(10,8))
plt.show()
# Out:
# [8.979684829959455, 8.688962564687987, 9.13426503970124, 9.573603812880853, 9.221617311543401, 9.371790934153035, 9.090864793076143, 9.063929191914047, 8.582839664031933, 9.074539748832215]
#
# [1.3918828439134772, 1.3874971138363927, 1.4101710752044183, 1.3754018235222156, 1.3311480433881708, 1.4185608016181823, 1.4179551894155018, 1.4082431885440714, 1.3950155369885382, 1.430777067012226]

# %%
users = np.array([5, 12, 9, 4, 8, 11, 5, 11, 6, 4])
delta = np.random.randint(3, 10, size=len(users))
data = []
data_users = []

for i, j in enumerate(users):
    data_users.append(users[i])
    data.append(users[i] + delta[i])

x = np.arange(0, len(data), 1)

fig, ax = plt.subplots()


data_line = ax.plot(x, data, label='Общее кол-во', marker='o')
mean_line = ax.plot(x, users, label='Использовавших', marker='o')

legend = ax.legend(loc='upper right')

plt.figure(figsize=(10,8))
plt.show()



# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
IT = data
ECE = data_users
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='Общее кол-во')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='Использовавших ')
 
# Adding Xticks
plt.xlabel('Дни', fontweight ='bold', fontsize = 15)
plt.ylabel('Кол-во пользователей', fontweight ='bold', fontsize = 15)

 
plt.legend()
plt.show()

# %%
random_values = np.ones(10) * 3
random_normals = np.random.normal(0, 0.4, 10)
res = random_values + random_normals
delta = np.random.randint(3, 10, size=len(users))

print(random_normals)
print(res)


values = []
delta_values = []

for i, j in enumerate(res):
    values.append(res[i])
    delta_values.append(users[i] + delta[i])
    
# print(values)
# print(delta_values)


# # set width of bar
# barWidth = 0.25
# fig = plt.subplots(figsize =(12, 8))
 
# # set height of bar
# IT = data
# ECE = data_users
 
# # Set position of bar on X axis
# br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
 
# # Make the plot
# plt.bar(br1, IT, color ='r', width = barWidth,
#         edgecolor ='grey', label ='Общее кол-во')
# plt.bar(br2, ECE, color ='g', width = barWidth,
#         edgecolor ='grey', label ='Использовавших ')
 
# # Adding Xticks
# plt.xlabel('Дни', fontweight ='bold', fontsize = 15)
# plt.ylabel('Кол-во пользователей', fontweight ='bold', fontsize = 15)

 
# plt.legend()
# plt.show()
# Out:
# [-0.75529334  0.49014917 -0.15236624 -0.11605854  0.42148005  0.41482603
#   0.05464932  0.77182979  0.63505228  0.1599079 ]
# [2.24470666 3.49014917 2.84763376 2.88394146 3.42148005 3.41482603
#  3.05464932 3.77182979 3.63505228 3.1599079 ]
